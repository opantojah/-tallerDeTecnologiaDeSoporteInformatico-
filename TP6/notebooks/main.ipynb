# %%
import pandas as pd
import numpy as np

def eliminarEspacios(valor):
    valor = valor.replace(" ","")
    return valor


def eliminarNan(valor):
    if valor == "nan":
        return np.nan


def pasarMinusculas(valor):
    if type(valor) == str:
        return valor.lower()
    else:
        return valor


def soloNumero(valor):
    valor = str(valor)
    for caracter in valor:
        if not caracter.isnumeric() and caracter != ".":
            valor = valor.replace(caracter, "")
    return valor


def generalizarSexos(valor):
    valor = str(valor)
    valor.lower()
    if valor.startswith('m') or valor.startswith('h'):
        valor = valor[0]
    elif valor.startswith('no binarie'):
        valor = 'nb'
    else:
        valor = np.nan
    return valor


def arreglarLU(valor):
    valor = str(valor)
    esPrimeraParte = True
    primeraParte = ""
    segundaParte = ""
    for caracter in valor:
        if caracter.isnumeric() and esPrimeraParte:
            primeraParte += caracter
        elif caracter.isnumeric() and not esPrimeraParte:
            segundaParte += caracter
        else:
            esPrimeraParte = False
    valor = primeraParte + "/" + segundaParte
    return valor


def generalizarObservacion(valor):
    a =  {"hiper":"hipertension", "cabeza":"dolor de cabeza"}
    valor = str(valor)
    for subS in a.keys():
        if subS in valor:
            valor = a.get(subS)
            return valor
    valor = "ninguna"
    return valor

print("asdasdasdasd")
data = pd.read_csv("../data/datos.csv", sep=',', skipinitialspace=True, engine='python')

#  ponemos formato especifico al sexo
data["Sexo"] = data["Sexo"].apply(generalizarSexos)

#  normalizamos las observaciones
data["Observación"] = data["Observación"].apply(generalizarObservacion)

#  eliminamos los espacios
data = data.apply(eliminarEspacios)

#  transformamos los nan
data = data.apply(eliminarNan)

#  borramos las filas con valores vacios
data = data.dropna()

#  pasamos todo el dataframe a minusculas
data = data.applymap(pasarMinusculas)

#  pasamos los promedios a float
data['Promedio'] = data['Promedio'].apply(float)

#  sacamos letras de Peso
data["Peso"] = data["Peso"].apply(soloNumero)

#  sacamos letras de Altura
data["Altura"] = data["Altura"].apply(soloNumero)

#  arreglamos el formato de LU
data["LU"] = data["LU"].apply(arreglarLU)


data.to_csv('../data/csvLimpio.csv')
# Out:
# asdasdasdasd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-b512592c9fb3> in <module>
#      78
#      79 #  transformamos los nan
# ---> 80 data = data.apply(eliminarNan)
#      81
#      82 #  borramos las filas con valores vacios
#
# ~/anaconda3/envs/TP6/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8734             kwargs=kwargs,
#    8735         )
# -> 8736         return op.apply()
#    8737
#    8738     def applymap(
#
# ~/anaconda3/envs/TP6/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/anaconda3/envs/TP6/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     803
#     804     def apply_standard(self):
# --> 805         results, res_index = self.apply_series_generator()
#     806
#     807         # wrap results
#
# ~/anaconda3/envs/TP6/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     819             for i, v in enumerate(series_gen):
#     820                 # ignore SettingWithCopy here in case the user mutates
# --> 821                 results[i] = self.f(v)
#     822                 if isinstance(results[i], ABCSeries):
#     823                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-1-b512592c9fb3> in eliminarNan(valor)
#       8
#       9 def eliminarNan(valor):
# ---> 10     if valor == "nan":
#      11         return np.nan
#      12
#
# ~/anaconda3/envs/TP6/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1532     @final
#    1533     def __nonzero__(self):
# -> 1534         raise ValueError(
#    1535             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1536             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
