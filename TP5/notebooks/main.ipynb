# %%
import pandas as pd
import matplotlib.pyplot as plt1
import matplotlib.pyplot as plt2
import matplotlib.pyplot as plt3
import main as funciones


data = pd.read_csv("../data/asd - Respuestas de formulario 1.csv")
# grafico 1

x = data['Cual de las siguientes bebidas es la que mas te gusta?'].unique()
y = data['Cual de las siguientes bebidas es la que mas te gusta?'].value_counts()

plt1.title('Bebidas preferidas')
plt1.bar(x,y)
plt1.xlabel('Bebidas')
plt1.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
# grafico 2

x2 = data['Que endulzante elegis que tenga la bebida?'].unique()
y2 = data['Que endulzante elegis que tenga la bebida?'].value_counts()

plt2.title('Endulzantes preferidos')
plt2.bar(x2,y2)
plt2.xlabel('Endulzantes')
plt2.ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
def armarDicc():
    d = {}
    for i in x:
        d[i] = []
    return d

def sacarPromedio():
    dicc = armarDicc()
    nombresBebida = data["Cual de las siguientes bebidas es la que mas te gusta?"]
    cantLts = data['Semanalmente, cuantos litros consumis de la bebida elegida? (Ingrese solamente el numero)']
    for bebida in x:
        for row in range(len(data)): #
            if bebida == nombresBebida[row]:
                dicc[bebida].append(cantLts[row])
    print(dicc)
    for i in dicc.values():
        suma = 0
        for val in i:
            suma = suma + val
        y.append(suma / len(i))
    
# grafico 3
#
x = data['Cual de las siguientes bebidas es la que mas te gusta?'].unique()
# y = data['Semanalmente, cuantos litros consumis de la bebida elegida? (Ingrese solamente el numero)'] # ver como calcular el promedio
#
y = []

sacarPromedio()


plt3.title('Promedio de litros semanales por bebida preferida')
plt3.bar(x,y)
plt3.xlabel('Bebidas')
plt3.ylabel('Cantidad litros (promedio)')
# Out:
# {'Soda (agua con gas)': [10.0], 'Bichi-cola': [10.0, 10.0], 'Agua': [21.0, 10.0, 7.0, 24.0, 1.5, 20.0, 4.0, 10.0, nan], 'Fanta': [0.0], 'Coca-cola (linea cola)': [0.5, 3.0, 2.0, 1.0], 'Jugo clight': [28.0], 'bichy cola': [3.0], 'Sprite': [1.0], 'Pepsi (linea cola)': [0.0], 'bichi': [20.0], 'Agua saborizada': [28.0, 1.0], 'Sangre fermentada': [5.0], 'Agua tonica': [2.0]}
# Text(0, 0.5, 'Cantidad litros (promedio)')

# %% [markdown]
# ##### Primer grafico, cantidad por bebida
# ##### Segundo, cantidad por endulzante
# ##### Tercero, promedio de litros semanales por bebida
#
# ### link del form: https://forms.gle/KFouvYVeLXbfiDVn8

# %%
##### Primer grafico, cantidad por bebida
##### Segundo, cantidad por endulzante
##### Tercero, promedio de litros semanales por bebida

### link del form: https://forms.gle/KFouvYVeLXbfiDVn8
# Out:
# 17/06/2021 18:03:37
# 17/06/2021 18:11:24
# 17/06/2021 19:26:15
# 17/06/2021 19:26:43
# 17/06/2021 20:32:14
# 17/06/2021 21:34:22
# 17/06/2021 22:04:55
# 17/06/2021 23:03:23
# 18/06/2021 0:16:39
# 18/06/2021 0:17:52
# 18/06/2021 0:20:48
# 18/06/2021 0:21:44
# 18/06/2021 9:13:05
# 18/06/2021 9:13:29
# 18/06/2021 9:13:43
# 23/06/2021 19:56:16
# 24/06/2021 8:27:52
# 24/06/2021 8:33:15
# 24/06/2021 9:07:57
# 24/06/2021 9:08:21
# 24/06/2021 9:08:34
# 24/06/2021 9:23:15
# 24/06/2021 9:25:45
# 24/06/2021 9:47:17
# 24/06/2021 10:31:16
# 24/06/2021 13:52:16
# Soda (agua con gas)
# Bichi-cola
# Agua
# Agua
# Fanta
# Coca-cola (linea cola)
# Agua
# Jugo clight
# Agua
# Agua
# Agua
# bichy cola
# Sprite
# Pepsi (linea cola)
# bichi
# Coca-cola (linea cola)
# Agua saborizada
# Agua
# Agua
# Bichi-cola
# Coca-cola (linea cola)
# Agua
# Coca-cola (linea cola)
# Sangre fermentada
# Agua tonica
# Agua saborizada
# No aplica
# Azucar
# No aplica
# No aplica
# Azucar
# Azucar
# Edulcorante
# No aplica
# Edulcorante
# No aplica
# No aplica
# Edulcorante
# No aplica
# Edulcorante
# Edulcorante
# Azucar
# Edulcorante
# Azucar
# No aplica
# Azucar
# No aplica
# Azucar
# Azucar
# Edulcorante
# No aplica
# No aplica
# 10
# 10
# 21
# 10
# 0 😭😭😭
# 0.5
# 7
# 28
# 24
# 1.5
# 20
# 3
# 1
# 0
# 20
# 3
# 28
# 4
# 10
# 10
# 2
# nan
# 1
# 5
# 2
# 1
#    Marca temporal Cual de las siguientes bebidas es la que mas te gusta?  \
# 0            None                                               None
# 1            None                                               None
# 2            None                                               None
# 3            None                                               None
# 4            None                                               None
# 5            None                                               None
# 6            None                                               None
# 7            None                                               None
# 8            None                                               None
# 9            None                                               None
# 10           None                                               None
# 11           None                                               None
# 12           None                                               None
# 13           None                                               None
# 14           None                                               None
# 15           None                                               None
# 16           None                                               None
# 17           None                                               None
# 18           None                                               None
# 19           None                                               None
# 20           None                                               None
# 21           None                                               None
# 22           None                                               None
# 23           None                                               None
# 24           None                                               None
# 25           None                                               None
#
#    Que endulzante elegis que tenga la bebida?  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# 9                                        None
# 10                                       None
# 11                                       None
# 12                                       None
# 13                                       None
# 14                                       None
# 15                                       None
# 16                                       None
# 17                                       None
# 18                                       None
# 19                                       None
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25                                       None
#
#    Semanalmente, cuantos litros consumis de la bebida elegida? (Ingrese solamente el numero)
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None

# %% [markdown]
# ##### Primer grafico, cantidad por bebida
# ##### Segundo, cantidad por endulzante
# ##### Tercero, promedio de litros semanales por bebida
#
# ### link del form: https://forms.gle/KFouvYVeLXbfiDVn8
